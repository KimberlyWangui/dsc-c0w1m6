# %% [markdown]
# # Practice for Seaborn

# %%
# Import packages
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Import data

penguins = sns.load_dataset("penguins")

# %% [markdown]
# 1. Recreate the scatter plot image you see below using Seaborn.  Use ‘flipper_length_mm’ on the x-axis and ‘body_mass_g’ on the y-axis.  The dataset called ‘penguins’ has already been imported for you in the first cell.

# %% [markdown]
# ![scatterPlot.png](data:image/png;base64,...)

# %%
# Your code here
ax = sns.scatterplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")

# add title and labels
ax.set(title="Penguin Bill Dimensions", xlabel="flipper_length_mm", ylabel="body_mass_g")

# Display the plot
plt.show()

# %% [markdown]
# 2. Using the same code from question 1, add an additional ‘hue’ argument and set that equal to the variable ‘species’.  You should get the image you see below displaying three distinct colors.

# %%
# Your code here
ax = sns.scatterplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", hue="species")

# add title and labels
ax.set(title="Penguin Bill Dimensions", xlabel="flipper_length_mm", ylabel="body_mass_g")

# Display the plot
plt.show()

# %% [markdown]
# 3. Now add one more argument, ‘size’, and set it equal to the variable ‘bill_length_mm’.  Also, add an additional argument, ‘style’, and set that equal to the variable ‘species’.   You should get the visual below

# %%
# Your code here
ax = sns.scatterplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", hue="species", size='bill_length_mm', style='species')

# add title and labels
ax.set(title="Penguin Bill Dimensions", xlabel="flipper_length_mm", ylabel="body_mass_g")

# Display the plot
plt.show()
